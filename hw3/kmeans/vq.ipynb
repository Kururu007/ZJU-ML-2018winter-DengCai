# %% [markdown]
# # K-Means and VQ
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. Please check the pdf file for more details.*
#
# In this exercise you will:
#
# - implement the **K-Means clustering** algorithm
# - play with the hyperparameter K
# - implement the Vector Quantization with K-Means
#
# Please note that **YOU CANNOT USE ANY MACHINE LEARNING PACKAGE SUCH AS SKLEARN** for any homework, unless you are asked.

# %%
# some basic imports
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Run your k-means algorithm on `kmeans_data.mat`. Note that the lines indicate the iterations of centroids.

# %%
from kmeans import kmeans
from kmeans_plot import kmeans_plot
x = sio.loadmat('kmeans_data.mat')['X']
k = 2  # modify if you want
max_sd = -1
min_sd = np.inf
for i in range(1000):
    idx, ctrs, iter_ctrs = kmeans(x, k)
    s = 0
    for j in range(x.shape[0]):
        s += np.linalg.norm(x[j, :] - ctrs[int(idx[j]), :])
    if s > max_sd:
            max_idx = idx
            max_ctrs = ctrs
            max_iter_ctrs = iter_ctrs
            max_sd = s
    if s < min_sd:
            min_idx = idx
            min_ctrs = ctrs
            min_iter_ctrs = iter_ctrs
            min_sd = s
kmeans_plot(x, max_idx, max_ctrs, max_iter_ctrs);
kmeans_plot(x, min_idx, min_ctrs, min_iter_ctrs);

# %%
from kmeans import kmeans
from kmeans_plot import kmeans_plot
x = sio.loadmat('kmeans_data.mat')['X']
k = 2  # modify if you want
idx, ctrs, iter_ctrs = kmeans(x, k)
kmeans_plot(x, idx, ctrs, iter_ctrs)

# %% [markdown]
# Run your k-means algorithm on the digit dataset `digit_data.mat`.

# %%
from show_digit import show_digit
x = sio.loadmat('digit_data.mat')['X']
for k in [10, 20, 50]:
    _, ctrs, _ = kmeans(x, k)
    show_digit(ctrs)

# %% [markdown]
# # Vector quantization
# Compress images with K set to 8, 16, 32 and 64.

# %%
from kmeans import kmeans
from matplotlib.pyplot import imread
import math
img = imread('trump.jpg')
fea = img.reshape((img.shape[0]*img.shape[1], 3)).astype(np.float64)
# YOUR (SEVERAL LINES) CODE HERE
# begin answer
K = [8]
for k in K:
    idx, ctrs, _ = kmeans(fea, k)
    fea_ = np.zeros(fea.shape)
    for i, index in enumerate(idx):
        fea_[int(i), :] = ctrs[int(index), :]
    plt.imshow(fea_.reshape(img.shape).astype(np.uint8))
    print("The compression ratio is {}".format(24/math.log2(k)))
# end answer
# Out:
# The compression ratio is 8.0

# %%
from kmeans import kmeans
from matplotlib.pyplot import imread
import math
img = imread('trump.jpg')
fea = img.reshape((img.shape[0]*img.shape[1], 3)).astype(np.float64)
# YOUR (SEVERAL LINES) CODE HERE
# begin answer
K = [16]
for k in K:
    idx, ctrs, _ = kmeans(fea, k)
    fea_ = np.zeros(fea.shape)
    for i, index in enumerate(idx):
        fea_[int(i), :] = ctrs[int(index), :]
    plt.imshow(fea_.reshape(img.shape).astype(np.uint8))
    print("The compression ratio is {}".format(24/math.log2(k)))
# end answer
# Out:
# The compression ratio is 6.0

# %%
from kmeans import kmeans
from matplotlib.pyplot import imread
import math
img = imread('trump.jpg')
fea = img.reshape((img.shape[0]*img.shape[1], 3)).astype(np.float64)
# YOUR (SEVERAL LINES) CODE HERE
# begin answer
K = [32]
for k in K:
    idx, ctrs, _ = kmeans(fea, k)
    fea_ = np.zeros(fea.shape)
    for i, index in enumerate(idx):
        fea_[int(i), :] = ctrs[int(index), :]
    plt.imshow(fea_.reshape(img.shape).astype(np.uint8))
    print("The compression ratio is {}".format(24/math.log2(k)))
# end answer
# Out:
# The compression ratio is 4.8

# %%
from kmeans import kmeans
from matplotlib.pyplot import imread
import math
img = imread('trump.jpg')
fea = img.reshape((img.shape[0]*img.shape[1], 3)).astype(np.float64)
# YOUR (SEVERAL LINES) CODE HERE
# begin answer
K = [64]
for k in K:
    idx, ctrs, _ = kmeans(fea, k)
    fea_ = np.zeros(fea.shape)
    for i, index in enumerate(idx):
        fea_[int(i), :] = ctrs[int(index), :]
    plt.imshow(fea_.reshape(img.shape).astype(np.uint8))
    print("The compression ratio is {}".format(24/math.log2(k)))
# Out:
# The compression ratio is 4.0

# %%
from kmeans import kmeans
from matplotlib.pyplot import imread
import math
img = imread('sample0.jpg')
fea = img.reshape((img.shape[0]*img.shape[1], 3)).astype(np.float64)
# YOUR (SEVERAL LINES) CODE HERE
# begin answer
K = [8]
for k in K:
    idx, ctrs, _ = kmeans(fea, k)
    fea_ = np.zeros(fea.shape)
    for i, index in enumerate(idx):
        fea_[int(i), :] = ctrs[int(index), :]
    plt.imshow(fea_.reshape(img.shape).astype(np.uint8))
    print("The compression ratio is {}".format(24/math.log2(k)))

# %%
from kmeans import kmeans
from matplotlib.pyplot import imread
import math
img = imread('sample0.jpg')
fea = img.reshape((img.shape[0]*img.shape[1], 3)).astype(np.float64)
# YOUR (SEVERAL LINES) CODE HERE
# begin answer
K = [16]
for k in K:
    idx, ctrs, _ = kmeans(fea, k)
    fea_ = np.zeros(fea.shape)
    for i, index in enumerate(idx):
        fea_[int(i), :] = ctrs[int(index), :]
    plt.imshow(fea_.reshape(img.shape).astype(np.uint8))
    print("The compression ratio is {}".format(24/math.log2(k)))

# %%
from kmeans import kmeans
from matplotlib.pyplot import imread
import math
img = imread('sample0.jpg')
fea = img.reshape((img.shape[0]*img.shape[1], 3)).astype(np.float64)
# YOUR (SEVERAL LINES) CODE HERE
# begin answer
K = [32]
for k in K:
    idx, ctrs, _ = kmeans(fea, k)
    fea_ = np.zeros(fea.shape)
    for i, index in enumerate(idx):
        fea_[int(i), :] = ctrs[int(index), :]
    plt.imshow(fea_.reshape(img.shape).astype(np.uint8))
    print("The compression ratio is {}".format(24/math.log2(k)))

# %%
from kmeans import kmeans
from matplotlib.pyplot import imread
import math
img = imread('sample0.jpg')
fea = img.reshape((img.shape[0]*img.shape[1], 3)).astype(np.float64)
# YOUR (SEVERAL LINES) CODE HERE
# begin answer
K = [64]
for k in K:
    idx, ctrs, _ = kmeans(fea, k)
    fea_ = np.zeros(fea.shape)
    for i, index in enumerate(idx):
        fea_[int(i), :] = ctrs[int(index), :]
    plt.imshow(fea_.reshape(img.shape).astype(np.uint8))
    print("The compression ratio is {}".format(24/math.log2(k)))
